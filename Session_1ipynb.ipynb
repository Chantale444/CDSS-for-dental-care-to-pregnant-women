# %% [markdown]
# <a href="https://colab.research.google.com/github/Chantale444/CDSS-for-dental-care-to-pregnant-women/blob/main/Session_1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loops in python for repitition

# %%
for i in range(10):
  print ("Hello World ")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %% [markdown]
# Range starts counting from 0-9= 10 counts. It ends at n-1

# %% [markdown]
# Write a program to print numbers from 1 to 100

# %%
for i in range (1-101):
  print ("i")

# %%
for i in range (1-101):
  if 1 % 2 == 0:
    print (i)

# %% [markdown]
# When to use while loop. IS you do not know how many times a loop would run eg google serach infinite search.

# %%
total = 0
for i in range
 total = total + 1
 print (total)

# %% [markdown]
# IN while loop you manage counter yoursel, in for loop it goes automatically.

# %%
total = 0
i = 0

while i < 101:
  total = total + 1
  i = i + 1
print (total)
# Out:
# 101

# %%
Functions and lists. A function is a small block of code that does a specific

# %%
n = 100

result = (n * (n + ) / 2
print (result)
# Out:
#   File "/tmp/ipykernel_264/2248856286.py", line 3
#     result = (n * (n + ) / 2
#                        ^
# SyntaxError: invalid syntax

# %%
def greet-hello:¨print ("Hello")
greet_hello():
print("Goodbye")

# %% [markdown]
# A function takes an inout and produces an output.

# %%
#Write a program that calcuates the sum from 1 to n
def sum-till-n

# %%
def sum_till_n(n):
   sum  = 0
   for  i in range (n+1):
      sum += i
   return sum

# %%
#Write a code that prompts for a number and outputs the sum of the numbers from that number downwards.
n = int (input ("Enter n: "))
sum = 0
for i in range (n+1):
  sum += i

print("sum:", sum)
# Out:
# Enter n: 10
# sum: 55

# %%
result = result

# %% [markdown]
# Input two numbers from user, sum

# %% [markdown]
# Operands and operators. Arithmetic (+,-,/, %, *) logical, relational operators

# %%
#Write a program that takes as input two variables and calculates the sum, divident, multiplication and difference of the numbers
a = 10
b = 5
addition =  a + b
subtraction = a - b
multiplication = a * b
division = a / b
modulo = a % b

# %%
print(addition)
print(multiplication)
print(subtraction)
print(division)
print(modulo)
# Out:
# 15
# 50
# 5
# 2.0
# 0

# %%
#a program that takes 2 numbers as input and prints their sum
number_1 = int(input("enter a number: "))
number_2 = int(input("enter a number: "))
sum = number_1 + number_2
print(sum)
# Out:
# enter a number: 8
# enter a number: 8
# 16

# %% [markdown]
# Decissions (If, else, elif statements)

# %%
#Learning how to use if statement
flag = False
a = 5
b = 6
if flag == True:
   print("sum is a + b")
else:
   print("cannot do sum right now")
# Out:
# cannot do sum right now

# %%
#Write a program to build a calculator that performs the operations +,*,-,/ or % operators.
number_1 = int(input("enter a number: "))
number_2 = int(input("enter a number: "))
addition = number_1 + number_2
subtraction = number_1 - number_2
division = number_1 / number_2
multiplication = number_1 * number_2
print(addition)
# Out:
# enter a number: 7
# enter a number: 3
# 10

# %%
print(multiplication)
# Out:
# 21

# %%
print(division)
# Out:
# 2.3333333333333335
